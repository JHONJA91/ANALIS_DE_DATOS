# %% [markdown]
# # Base de Datos ipynb

# %%
x = 10
y = 50

print(f"El resultado de la suma: {x} + {y} es = {x+y}")
# Out:
# El resultado de la suma: 10 + 50 es = 60

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("C:/Users/jhonj/Desktop/T_Tech_2025/Analisis de datos/proyectos_notbooks/Evaluaciones_Agropecuarias_Municipales_EVA_20250323.csv")

# %%
df.head(3)
# Out:
#    CÓD.DEP.  DEPARTAMENTO  CÓD.MUN. MUNICIPIO GRUPO DE CULTIVO  \
# 0        15        BOYACA     15114  BUSBANZA       HORTALIZAS
# 1        25  CUNDINAMARCA     25754    SOACHA       HORTALIZAS
# 2        25  CUNDINAMARCA     25214      COTA       HORTALIZAS
#
#   SUBGRUPO DE CULTIVO CULTIVO DESAGREGACIÓN REGIONAL Y/O SISTEMA PRODUCTIVO  \
# 0              ACELGA  ACELGA                                        ACELGA
# 1              ACELGA  ACELGA                                        ACELGA
# 2              ACELGA  ACELGA                                        ACELGA
#
#     AÑO PERIODO  Área Sembrada(ha)  Área Cosechada(ha)  Producción (t)  \
# 0  2006   2006B                  2                   1               1
# 1  2006   2006B                 82                  80            1440
# 2  2006   2006B                  2                   2              26
#
#    Rendimiento (t/ha) ESTADO FISICO PRODUCCION NOMBRE CIENTIFICO  \
# ...

# %%
df.describe()
# Out:
#             CÓD.DEP.       CÓD.MUN.            AÑO  Área Sembrada(ha)  \
# count  206068.000000  206068.000000  206068.000000      206068.000000
# mean       40.322563   40747.534066    2012.455976         291.073825
# std        25.278662   25256.621906       3.479113        1153.602556
# min         5.000000    5001.000000    2006.000000           0.000000
# 25%        17.000000   17524.000000    2009.000000          10.000000
# 50%        41.000000   41357.000000    2013.000000          35.000000
# 75%        68.000000   68001.000000    2015.000000         151.000000
# max        99.000000   99773.000000    2018.000000       47403.000000
#
#        Área Cosechada(ha)  Producción (t)  Rendimiento (t/ha)
# count       206068.000000    2.060680e+05       202635.000000
# mean           249.419522    2.790726e+03            9.238820
# std            980.375226    4.511471e+04           14.888659
# min              0.000000    0.000000e+00            0.030000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206068 entries, 0 to 206067
# Data columns (total 17 columns):
#  #   Column                                         Non-Null Count   Dtype
# ---  ------                                         --------------   -----
#  0   CÓD.DEP.                                       206068 non-null  int64
#  1   DEPARTAMENTO                                   206068 non-null  object
#  2   CÓD.MUN.                                       206068 non-null  int64
#  3   MUNICIPIO                                      206067 non-null  object
#  4   GRUPO DE CULTIVO                               206068 non-null  object
#  5   SUBGRUPO DE CULTIVO                            206068 non-null  object
#  6   CULTIVO                                        206068 non-null  object
#  7   DESAGREGACIÓN REGIONAL Y/O SISTEMA PRODUCTIVO  206068 non-null  object
#  8   AÑO                                            206068 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# CÓD.DEP.                                            0
# DEPARTAMENTO                                        0
# CÓD.MUN.                                            0
# MUNICIPIO                                           1
# GRUPO DE CULTIVO                                    0
# SUBGRUPO DE CULTIVO                                 0
# CULTIVO                                             0
# DESAGREGACIÓN REGIONAL Y/O SISTEMA PRODUCTIVO       0
# AÑO                                                 0
# PERIODO                                             0
# Área Sembrada(ha)                                   0
# Área Cosechada(ha)                                  0
# Producción (t)                                      0
# Rendimiento (t/ha)                               3433
# ESTADO FISICO PRODUCCION                            0
# NOMBRE CIENTIFICO                                2857
# CICLO DE CULTIVO                                    0
# dtype: int64

# %%
df["DEPARTAMENTO"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='DEPARTAMENTO'>

# %%
DPT_TON = df.pivot_table(index="DEPARTAMENTO",columns="AÑO",values="Producción (t)")
DPT_TON.head(32)
# Out:
# AÑO                              2006          2007          2008  \
# DEPARTAMENTO
# AMAZONAS                    60.500000    205.260870    209.576000
# ANTIOQUIA                 1158.327759   2279.049273   2223.133283
# ARAUCA                    1535.416667   4388.150000   5231.034483
# ATLANTICO                  120.451613    494.669421    402.946128
# BOLIVAR                   1190.104167   1945.368852   2160.816062
# BOYACA                     887.316364    849.791070    920.410507
# CALDAS                     399.676768   1870.457921   1927.960000
# CAQUETA                    240.520000    816.403315    785.050761
# CASANARE                  1588.250000   1861.737452   2070.719557
# CAUCA                      326.702532   6680.333898   5831.816856
# CESAR                     1419.747748   1390.841310   1417.745000
# CHOCO                      314.842105    749.222222    645.634812
# CORDOBA                   1169.075758   2367.443902   2087.560364
# ...

# %%
sb.heatmap(DPT_TON,cmap="viridis")
# Out:
# <Axes: xlabel='AÑO', ylabel='DEPARTAMENTO'>

# %%
DPT_TON.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, AMAZONAS to VICHADA
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2006    31 non-null     float64
#  1   2007    31 non-null     float64
#  2   2008    31 non-null     float64
#  3   2009    31 non-null     float64
#  4   2010    31 non-null     float64
#  5   2011    31 non-null     float64
#  6   2012    32 non-null     float64
#  7   2013    32 non-null     float64
#  8   2014    32 non-null     float64
#  9   2015    32 non-null     float64
#  10  2016    32 non-null     float64
#  11  2017    32 non-null     float64
#  12  2018    32 non-null     float64
# dtypes: float64(13)
# memory usage: 3.5+ KB

# %%
#df["CULTIVO"].mode()
df["CULTIVO"].value_counts()
# Out:
# CULTIVO
# MAIZ         24965
# FRIJOL       14693
# TOMATE        9654
# YUCA          9488
# PLATANO       9048
#              ...
# CANYARANA        1
# BACURI           1
# LAUREL           1
# MORINGA          1
# TANGARANA        1
# Name: count, Length: 223, dtype: int64

# %%
CULTIVOS = df.pivot_table(index="CULTIVO",columns="DEPARTAMENTO",values="Producción (t)")
#pd.set_option("display.max.rows",None)
#pd.set_option("display.max.columns",None)
CULTIVOS.head()
# Out:
# DEPARTAMENTO  AMAZONAS   ANTIOQUIA  ARAUCA  ATLANTICO  BOLIVAR      BOYACA  \
# CULTIVO
# ACELGA             NaN  307.200000     NaN        NaN      NaN  292.619048
# ACHICORIA          4.0         NaN     NaN        NaN      NaN         NaN
# ACHIOTE            NaN    3.000000   265.0        NaN      NaN         NaN
# ACHIRA             NaN         NaN     NaN        NaN      NaN   27.230769
# AGRAZ              NaN    2.857143     NaN        NaN      NaN  995.176471
#
# DEPARTAMENTO  CALDAS  CAQUETA  CASANARE       CAUCA  ...  PUTUMAYO  QUINDIO  \
# CULTIVO                                              ...
# ACELGA           4.0      6.0       NaN  115.566667  ...    33.875      8.0
# ACHICORIA        NaN      NaN       NaN         NaN  ...       NaN      NaN
# ACHIOTE          NaN      NaN      21.0    6.000000  ...       NaN      NaN
# ACHIRA           NaN      NaN       NaN   24.920000  ...       NaN      NaN
# ...

# %%
df[df["DEPARTAMENTO"]=="NARIÑO"]
# Out:
#         CÓD.DEP. DEPARTAMENTO  CÓD.MUN.          MUNICIPIO GRUPO DE CULTIVO  \
# 88            52       NARIÑO     52385         LA LLANADA       HORTALIZAS
# 100           52       NARIÑO     52385         LA LLANADA       HORTALIZAS
# 114           52       NARIÑO     52203              COLON       HORTALIZAS
# 182           52       NARIÑO     52838          TUQUERRES       HORTALIZAS
# 196           52       NARIÑO     52838          TUQUERRES       HORTALIZAS
# ...          ...          ...       ...                ...              ...
# 206045        52       NARIÑO     52490      OLAYA HERRERA         FRUTALES
# 206046        52       NARIÑO     52621      ROBERTO PAYAN         FRUTALES
# 206047        52       NARIÑO     52835             TUMACO         FRUTALES
# 206048        52       NARIÑO     52520  FRANCISCO PIZARRO         FRUTALES
# 206049        52       NARIÑO     52427        MAGUI PAYAN         FRUTALES
#
#        SUBGRUPO DE CULTIVO CULTIVO  \
# ...
