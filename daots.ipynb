# %% [markdown]
# # Base de Datos ipynb
# #### DataSet EVA

# %%
x = 10
y = 50

print(f"El resultado de la suma: {x} + {y} es = {x+y}")
# Out:
# El resultado de la suma: 10 + 50 es = 60

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("C:/Users/jhonj/Desktop/T_Tech_2025/Analisis de datos/proyectos_notbooks/Evaluaciones_Agropecuarias_Municipales_EVA_20250323.csv")

# %%
df.head(3)
# Out:
#    CÓD.DEP.  DEPARTAMENTO  CÓD.MUN. MUNICIPIO GRUPO DE CULTIVO  \
# 0        15        BOYACA     15114  BUSBANZA       HORTALIZAS
# 1        25  CUNDINAMARCA     25754    SOACHA       HORTALIZAS
# 2        25  CUNDINAMARCA     25214      COTA       HORTALIZAS
#
#   SUBGRUPO DE CULTIVO CULTIVO DESAGREGACIÓN REGIONAL Y/O SISTEMA PRODUCTIVO  \
# 0              ACELGA  ACELGA                                        ACELGA
# 1              ACELGA  ACELGA                                        ACELGA
# 2              ACELGA  ACELGA                                        ACELGA
#
#     AÑO PERIODO  Área Sembrada(ha)  Área Cosechada(ha)  Producción (t)  \
# 0  2006   2006B                  2                   1               1
# 1  2006   2006B                 82                  80            1440
# 2  2006   2006B                  2                   2              26
#
#    Rendimiento (t/ha) ESTADO FISICO PRODUCCION NOMBRE CIENTIFICO  \
# ...

# %%
df.describe()
# Out:
#             CÓD.DEP.       CÓD.MUN.            AÑO  Área Sembrada(ha)  \
# count  206068.000000  206068.000000  206068.000000      206068.000000
# mean       40.322563   40747.534066    2012.455976         291.073825
# std        25.278662   25256.621906       3.479113        1153.602556
# min         5.000000    5001.000000    2006.000000           0.000000
# 25%        17.000000   17524.000000    2009.000000          10.000000
# 50%        41.000000   41357.000000    2013.000000          35.000000
# 75%        68.000000   68001.000000    2015.000000         151.000000
# max        99.000000   99773.000000    2018.000000       47403.000000
#
#        Área Cosechada(ha)  Producción (t)  Rendimiento (t/ha)
# count       206068.000000    2.060680e+05       202635.000000
# mean           249.419522    2.790726e+03            9.238820
# std            980.375226    4.511471e+04           14.888659
# min              0.000000    0.000000e+00            0.030000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206068 entries, 0 to 206067
# Data columns (total 17 columns):
#  #   Column                                         Non-Null Count   Dtype
# ---  ------                                         --------------   -----
#  0   CÓD.DEP.                                       206068 non-null  int64
#  1   DEPARTAMENTO                                   206068 non-null  object
#  2   CÓD.MUN.                                       206068 non-null  int64
#  3   MUNICIPIO                                      206067 non-null  object
#  4   GRUPO DE CULTIVO                               206068 non-null  object
#  5   SUBGRUPO DE CULTIVO                            206068 non-null  object
#  6   CULTIVO                                        206068 non-null  object
#  7   DESAGREGACIÓN REGIONAL Y/O SISTEMA PRODUCTIVO  206068 non-null  object
#  8   AÑO                                            206068 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# CÓD.DEP.                                            0
# DEPARTAMENTO                                        0
# CÓD.MUN.                                            0
# MUNICIPIO                                           1
# GRUPO DE CULTIVO                                    0
# SUBGRUPO DE CULTIVO                                 0
# CULTIVO                                             0
# DESAGREGACIÓN REGIONAL Y/O SISTEMA PRODUCTIVO       0
# AÑO                                                 0
# PERIODO                                             0
# Área Sembrada(ha)                                   0
# Área Cosechada(ha)                                  0
# Producción (t)                                      0
# Rendimiento (t/ha)                               3433
# ESTADO FISICO PRODUCCION                            0
# NOMBRE CIENTIFICO                                2857
# CICLO DE CULTIVO                                    0
# dtype: int64

# %%
df.groupby("DEPARTAMENTO")["Rendimiento (t/ha)"].sum().sort_values(ascending=True).plot.bar()
# Out:
# <Axes: xlabel='DEPARTAMENTO'>

# %%
df[df["CULTIVO"]=="PAPA"].groupby("DEPARTAMENTO")["Rendimiento (t/ha)"].sum().sort_values(ascending=True).plot.bar()
# Out:
# <Axes: xlabel='DEPARTAMENTO'>

# %%
#DPT_TON = df.pivot_table(index="DEPARTAMENTO",columns="AÑO",values="Producción (t)")
DPT_TON = df[df["CULTIVO"]=="PAPA"].pivot_table(index="DEPARTAMENTO",columns="AÑO",values="Producción (t)")
DPT_TON.head(32)
# Out:
# AÑO                        2006         2007         2008         2009  \
# DEPARTAMENTO
# ANTIOQUIA           5005.692308  4000.127273  3568.672414  3265.254545
# BOYACA              3269.362637  3677.772727  4219.880240  4399.026316
# CALDAS              1071.750000   812.666667   818.333333  1014.111111
# CASANARE                    NaN          NaN          NaN   115.000000
# CAUCA               2958.333333  2929.789474  2798.888889  2502.800000
# CHOCO                       NaN          NaN          NaN    45.000000
# CUNDINAMARCA        8911.661765  7676.321429  7437.571429  8719.709220
# GUAVIARE                    NaN          NaN          NaN     0.000000
# HUILA                 67.500000    42.636364    39.416667    29.785714
# META                        NaN          NaN          NaN          NaN
# NARIÑO              9205.068966  7868.765625  6641.838235  7886.723684
# NORTE DE SANTANDER  5815.454545  4325.909091  3060.954545  3508.227273
# ...

# %%
sb.heatmap(DPT_TON,cmap="viridis")
# Out:
# <Axes: xlabel='AÑO', ylabel='DEPARTAMENTO'>

# %%
DPT_TON.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, AMAZONAS to VICHADA
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2006    31 non-null     float64
#  1   2007    31 non-null     float64
#  2   2008    31 non-null     float64
#  3   2009    31 non-null     float64
#  4   2010    31 non-null     float64
#  5   2011    31 non-null     float64
#  6   2012    32 non-null     float64
#  7   2013    32 non-null     float64
#  8   2014    32 non-null     float64
#  9   2015    32 non-null     float64
#  10  2016    32 non-null     float64
#  11  2017    32 non-null     float64
#  12  2018    32 non-null     float64
# dtypes: float64(13)
# memory usage: 3.5+ KB

# %%
df["CULTIVO"].mode()
# Out:
# 0    MAIZ
# Name: CULTIVO, dtype: object

# %%
df[df["Área Cosechada(ha)"]>=30000]
# Out:
#         CÓD.DEP.     DEPARTAMENTO  CÓD.MUN.             MUNICIPIO  \
# 45473         76  VALLE DEL CAUCA     76520               PALMIRA
# 45575         76  VALLE DEL CAUCA     76520               PALMIRA
# 45738         76  VALLE DEL CAUCA     76520               PALMIRA
# 45792         76  VALLE DEL CAUCA     76520               PALMIRA
# 45849         76  VALLE DEL CAUCA     76520               PALMIRA
# 45902         76  VALLE DEL CAUCA     76520               PALMIRA
# 45953         76  VALLE DEL CAUCA     76520               PALMIRA
# 108326        50             META     50568         PUERTO GAITAN
# 108739        50             META     50568         PUERTO GAITAN
# 109140        50             META     50568         PUERTO GAITAN
# 144562        68        SANTANDER     68575        PUERTO WILCHES
# 144656        68        SANTANDER     68575        PUERTO WILCHES
# 144756        68        SANTANDER     68575        PUERTO WILCHES
# ...

# %% [markdown]
# La mayor producción Cosechada en Hectareas

# %%
df[df["Área Cosechada(ha)"]== df["Área Cosechada(ha)"].max()]
# Out:
#         CÓD.DEP. DEPARTAMENTO  CÓD.MUN.             MUNICIPIO  \
# 144945        50         META     50680  SAN CARLOS DE GUAROA
#
#        GRUPO DE CULTIVO SUBGRUPO DE CULTIVO          CULTIVO  \
# 144945      OLEAGINOSAS     PALMA DE ACEITE  PALMA DE ACEITE
#
#        DESAGREGACIÓN REGIONAL Y/O SISTEMA PRODUCTIVO   AÑO PERIODO  \
# 144945                               PALMA DE ACEITE  2011    2011
#
#         Área Sembrada(ha)  Área Cosechada(ha)  Producción (t)  \
# 144945              43600               38600          115800
#
#         Rendimiento (t/ha) ESTADO FISICO PRODUCCION  NOMBRE CIENTIFICO  \
# 144945                 3.0             ACEITE CRUDO  ELAEIS GUINEENSIS
#
#        CICLO DE CULTIVO
# 144945       PERMANENTE

# %% [markdown]
# La menor producción Cosechada en Hectareas

# %%
#df[(df["Área Cosechada(ha)"] == df["Área Cosechada(ha)"].min()) & (df["Área Cosechada(ha)"]>0)]
df[(df["Área Cosechada(ha)"] >0) & (df["CULTIVO"]=="PAPA") & (df["DEPARTAMENTO"] =="NARIÑO") & (df["MUNICIPIO"] =="PUERRES")]
# Out:
#         CÓD.DEP. DEPARTAMENTO  CÓD.MUN. MUNICIPIO       GRUPO DE CULTIVO  \
# 146188        52       NARIÑO     52573   PUERRES  TUBERCULOS Y PLATANOS
# 146436        52       NARIÑO     52573   PUERRES  TUBERCULOS Y PLATANOS
# 146663        52       NARIÑO     52573   PUERRES  TUBERCULOS Y PLATANOS
# 146897        52       NARIÑO     52573   PUERRES  TUBERCULOS Y PLATANOS
# 147138        52       NARIÑO     52573   PUERRES  TUBERCULOS Y PLATANOS
# 147376        52       NARIÑO     52573   PUERRES  TUBERCULOS Y PLATANOS
# 147614        52       NARIÑO     52573   PUERRES  TUBERCULOS Y PLATANOS
# 147861        52       NARIÑO     52573   PUERRES  TUBERCULOS Y PLATANOS
# 148098        52       NARIÑO     52573   PUERRES  TUBERCULOS Y PLATANOS
# 148346        52       NARIÑO     52573   PUERRES  TUBERCULOS Y PLATANOS
# 148575        52       NARIÑO     52573   PUERRES  TUBERCULOS Y PLATANOS
# 148824        52       NARIÑO     52573   PUERRES  TUBERCULOS Y PLATANOS
# ...

# %%
#suma_puerres = df[(df["Área Cosechada(ha)"] >0) & (df["CULTIVO"]=="PAPA") & (df["DEPARTAMENTO"] =="NARIÑO") & (df["MUNICIPIO"] =="PUERRES")]["Área Cosechada(ha)"].sum()
suma_puerres = df[(df["MUNICIPIO"]=="PUERRES")&(df["CULTIVO"]=="PAPA")]["Área Cosechada(ha)"].sum()
#suma_puerres = df[df["MUNICIPIO"]=="PUERRES"]
print(f"la suma de total de hectareas de papa cosechadas es: {suma_puerres}")
# Out:
# la suma de total de hectareas de papa cosechadas es: 3888

# %%
df[df["DEPARTAMENTO"]=="NARIÑO"].groupby("CULTIVO")["Área Cosechada(ha)"].sum().reset_index()
#categ = df.groupby("MUNICIPIO")["Área Cosechada(ha)"].sum().reset_index()[df["DEPARTAMENTO"]=="NARIÑO"]
#categ
# Out:
#        CULTIVO  Área Cosechada(ha)
# 0       ACELGA                  28
# 1       ACHIRA                3811
# 2     AGUACATE                1877
# 3          AJI                  15
# 4          AJO                1505
# ..         ...                 ...
# 96         UVA                  11
# 97        YUCA               21353
# 98   ZANAHORIA               15419
# 99      ZAPOTE                1190
# 100       ÑAME                  57
#
# [101 rows x 2 columns]

# %%
df[df["DEPARTAMENTO"]=="NARIÑO"].groupby(["MUNICIPIO","CULTIVO","AÑO"])["Producción (t)"].sum().reset_index()
# Out:
#         MUNICIPIO    CULTIVO   AÑO  Producción (t)
# 0           ALBAN     ACHIRA  2012               6
# 1           ALBAN     ACHIRA  2013               6
# 2           ALBAN     ACHIRA  2014               9
# 3           ALBAN     ACHIRA  2015               5
# 4           ALBAN     ACHIRA  2016               4
# ...           ...        ...   ...             ...
# 10164  YACUANQUER  ZANAHORIA  2007             308
# 10165  YACUANQUER  ZANAHORIA  2008             220
# 10166  YACUANQUER  ZANAHORIA  2012              81
# 10167  YACUANQUER  ZANAHORIA  2013              81
# 10168  YACUANQUER  ZANAHORIA  2015              51
#
# [10169 rows x 4 columns]
